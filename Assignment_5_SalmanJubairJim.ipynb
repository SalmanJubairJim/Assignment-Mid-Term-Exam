# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import numpy as np
np.random.seed(42)
import os
import matplotlib.pyplot as plt
import glob
import pandas as pd

import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras import layers
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras import layers, Model
from sklearn.model_selection import train_test_split

from keras import Model
from keras.layers import Conv2D, PReLU,BatchNormalization, Flatten
from keras.layers import UpSampling2D, LeakyReLU, Dense, Input, add
from tqdm import tqdm

# %%
#directory
train_dir = "/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train" 

# Test data
test_dir = "/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/test"

# %%
# DME images from train folder
train_DME = train_dir+"/DME"

# DRUSEN images from train folder
train_DRUSEN = train_dir+"/DRUSEN"

data = [] 

# get a list of all image files in the folder 
image_train_DME = glob.glob(os.path.join(train_DME, '*.jpg')) + glob.glob(os.path.join(train_DME, '*.jpeg')) + glob.glob(os.path.join(train_DME, '*.png'))

# iterate through the list of image files
for file in image_train_DME:

     image = {"label": 1, "image_path" : file }
     data.append(image)

# get a list of all image files in the folder 
image_train_DRUSEN = glob.glob(os.path.join(train_DRUSEN, '*.jpg')) + glob.glob(os.path.join(train_DRUSEN, '*.jpeg')) + glob.glob(os.path.join(train_DRUSEN, '*.png'))

# iterate through the list of image files
for file in image_train_DRUSEN:

     image = {"label": 0, "image_path" : file }
     data.append(image)


# making data into a dataframe
df = pd.DataFrame(data)

# shuffle the DataFrame rows
df = df.sample(frac = 1, random_state=42)

# DME = 1, DRUSEN = 0
df
# Out:
#       label                                         image_path
# 2311      0  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 2059      0  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 194       1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 1393      1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 764       1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# ...     ...                                                ...
# 1638      0  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 1095      1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 1130      1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 1294      1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
# 860       1  /content/drive/MyDrive/Colab Notebooks/A5/Data...
#
# [2534 rows x 2 columns]

# %%
for class_name in ["DME", "DRUSEN"]:
    hr_dir = train_dir + "/hr_images_" + class_name
    lr_dir = train_dir + "/lr_images_" + class_name
    os.makedirs(hr_dir, exist_ok=True)
    os.makedirs(lr_dir, exist_ok=True)
    for img in os.listdir(train_dir + "/" + class_name):
        img_array = cv2.imread(train_dir + "/" + class_name + "/" + img)
        
        img_array = cv2.resize(img_array, (128,128))
        lr_img_array = cv2.resize(img_array,(32,32))
        cv2.imwrite(hr_dir + "/" + img, img_array)
        cv2.imwrite(lr_dir + "/" + img, lr_img_array)

# %%
import matplotlib.pyplot as plt
import os

class_name = "DME"  # choose which class to visualize
hr_dir = train_dir + "/hr_images_" + class_name
lr_dir = train_dir + "/lr_images_" + class_name

# get a list of image file names
img_files = os.listdir(hr_dir)

# choose how many images to visualize
num_images = 2

# plot the images
fig, ax = plt.subplots(num_images, 2, figsize=(8, 16))
for i in range(num_images):
    # read the high-resolution image
    hr_img = plt.imread(os.path.join(hr_dir, img_files[i]))
    # read the low-resolution image
    lr_img = plt.imread(os.path.join(lr_dir, img_files[i]))
    # plot the images side by side
    ax[i, 0].imshow(hr_img)
    ax[i, 1].imshow(lr_img)
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()
print('hr_img.shape:', hr_img.shape)
print('lr_img.shape:', lr_img.shape)
# Out:
# hr_img.shape: (128, 128, 3)
# lr_img.shape: (32, 32, 3)

# %%
class_name = "DRUSEN"  # choose which class to visualize
hr_dir = train_dir + "/hr_images_" + class_name
lr_dir = train_dir + "/lr_images_" + class_name

# get a list of image file names
img_files = os.listdir(hr_dir)

# choose how many images to visualize
num_images = 2

# plot the images
fig, ax = plt.subplots(num_images, 2, figsize=(8, 16))
for i in range(num_images):
    # read the high-resolution image
    hr_img = plt.imread(os.path.join(hr_dir, img_files[i]))
    # read the low-resolution image
    lr_img = plt.imread(os.path.join(lr_dir, img_files[i]))
    # plot the images side by side
    ax[i, 0].imshow(hr_img)
    ax[i, 1].imshow(lr_img)
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()
print('hr_img.shape:', hr_img.shape)
print('lr_img.shape:', lr_img.shape)
# Out:
# hr_img.shape: (128, 128, 3)
# lr_img.shape: (32, 32, 3)

# %%
#Define blocks to build the generator
def res_block(ip):
    
    res_model = Conv2D(64, (3,3), padding = "same")(ip)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    res_model = PReLU(shared_axes = [1,2])(res_model)
    
    res_model = Conv2D(64, (3,3), padding = "same")(res_model)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    
    return add([ip,res_model])

def upscale_block(ip):
    
    up_model = Conv2D(256, (3,3), padding="same")(ip)
    up_model = UpSampling2D( size = 2 )(up_model)
    up_model = PReLU(shared_axes=[1,2])(up_model)
    
    return up_model

# %%
#Generator model
def create_gen(gen_ip, num_res_block):
    layers = Conv2D(64, (3,3), padding="same")(gen_ip)
    layers = PReLU(shared_axes=[1,2])(layers)

    temp = layers

    for i in range(num_res_block):
        layers = res_block(layers)

    layers = Conv2D(64, (3,3), padding="same")(layers)
    layers = BatchNormalization(momentum=0.5)(layers)
    layers = add([layers,temp])

    layers = upscale_block(layers)
    layers = upscale_block(layers)

    op = Conv2D(3, (9,9), padding="same")(layers)

    return Model(inputs=gen_ip, outputs=op)

# %%
#Descriminator block that will be used to construct the discriminator
def discriminator_block(ip, filters, strides=1, bn=True):
    
    disc_model = Conv2D(filters, (3,3), strides = strides, padding="same")(ip)
    
    if bn:
        disc_model = BatchNormalization( momentum=0.8 )(disc_model)
    
    disc_model = LeakyReLU( alpha=0.2 )(disc_model)
    
    return disc_model

# %%
#Descriminartor, as described in the original paper
def create_disc(disc_ip):

    df = 64
    
    d1 = discriminator_block(disc_ip, df, bn=False)
    d2 = discriminator_block(d1, df, strides=2)
    d3 = discriminator_block(d2, df*2)
    d4 = discriminator_block(d3, df*2, strides=2)
    d5 = discriminator_block(d4, df*4)
    d6 = discriminator_block(d5, df*4, strides=2)
    d7 = discriminator_block(d6, df*8)
    d8 = discriminator_block(d7, df*8, strides=2)
    
    d8_5 = Flatten()(d8)
    d9 = Dense(df*16)(d8_5)
    d10 = LeakyReLU(alpha=0.2)(d9)
    validity = Dense(1, activation='sigmoid')(d10)

    return Model(disc_ip, validity)

# %%
from keras.applications import VGG19

def build_vgg(hr_shape):
    
    vgg = VGG19(weights="imagenet",include_top=False, input_shape=hr_shape)
    
    return Model(inputs=vgg.inputs, outputs=vgg.layers[10].output)

# %%
#Combined model
def create_comb(gen_model, disc_model, vgg, lr_ip, hr_ip):
    gen_img = gen_model(lr_ip)
    
    gen_features = vgg(gen_img)
    
    disc_model.trainable = False
    validity = disc_model(gen_img)
    
    return Model(inputs=[lr_ip, hr_ip], outputs=[validity, gen_features])

# %%
n = 1000

lr_images = []
hr_images = []

for class_name in ["DME", "DRUSEN"]:
    lr_list = os.listdir("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/lr_images_" + class_name)[:n]
    for img in lr_list:
        img_lr = cv2.imread("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/lr_images_" + class_name + "/" + img)
        img_lr = cv2.cvtColor(img_lr, cv2.COLOR_BGR2RGB)
        lr_images.append(img_lr)   
    
    hr_list = os.listdir("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/hr_images_" + class_name)[:n]
    for img in hr_list:
        img_hr = cv2.imread("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/hr_images_" + class_name + "/" + img)
        img_hr = cv2.cvtColor(img_hr, cv2.COLOR_BGR2RGB)
        hr_images.append(img_hr) 

lr_images = np.array(lr_images)
hr_images = np.array(hr_images)

# %%
#view few mages
import random
image_number = random.randint(0, len(lr_images)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(lr_images[image_number], (32, 32, 3)))
plt.subplot(122)
plt.imshow(np.reshape(hr_images[image_number], (128, 128, 3)))
plt.show()

# %%
#Scale values
lr_images = lr_images / 255.
hr_images = hr_images / 255.

# %%
import tensorflow as tf
data_augmentation = tf.keras.Sequential([
  layers.Resizing(32,32),
  layers.Rescaling(1./255),
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

# %%
from shutil import copyfile

# Define the parent directory of the dataset
data_dir = '/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train'

# Define the subdirectories for the train set
train_subdirs = ['hr_images_DME', 'hr_images_DRUSEN', 'lr_images_DME', 'lr_images_DRUSEN']

# Define the percentage of images to use for the train set
train_pct = 0.7

# Loop over the subdirectories and split the images into train and test sets
for subdir in train_subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    files = os.listdir(subdir_path)
    files = [os.path.join(subdir_path, file) for file in files]

    # Shuffle the files randomly
    random.shuffle(files)

    # Split the files into train and test sets
    train_files = files[:int(len(files) * train_pct)]
    test_files = files[int(len(files) * train_pct):]

    # Copy the train files to the train directory
    for file in train_files:
        filename = os.path.basename(file)
        dst_path = os.path.join(data_dir, filename)
        copyfile(file, dst_path)

    # Copy the test files to the test directory
    for file in test_files:
        filename = os.path.basename(file)
        dst_path = os.path.join(data_dir, filename)
        copyfile(file, dst_path)

    print('Finished splitting images for subdirectory:', subdir)

print('Split Done')
# Out:
# Finished splitting images for subdirectory: hr_images_DME
# Finished splitting images for subdirectory: hr_images_DRUSEN
# Finished splitting images for subdirectory: lr_images_DME
# Finished splitting images for subdirectory: lr_images_DRUSEN
# Split Done

# %%
lr_images = []
hr_images = []

for class_name in ["DME", "DRUSEN"]:
    lr_list = os.listdir("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/lr_images_" + class_name)[:n]
    for img in lr_list:
        img_lr = cv2.imread("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/lr_images_" + class_name + "/" + img)
        img_lr = cv2.cvtColor(img_lr, cv2.COLOR_BGR2RGB)
        lr_images.append(img_lr)   
    
    hr_list = os.listdir("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/hr_images_" + class_name)[:n]
    for img in hr_list:
        img_hr = cv2.imread("/content/drive/MyDrive/Colab Notebooks/A5/Data_Small/train/hr_images_" + class_name + "/" + img)
        img_hr = cv2.cvtColor(img_hr, cv2.COLOR_BGR2RGB)
        hr_images.append(img_hr) 

lr_images = np.array(lr_images)
hr_images = np.array(hr_images)

# %%
print(num_res_block)
# Out:
# 16

# %%
lr_train, lr_test, hr_train, hr_test = train_test_split(lr_images, hr_images, 
                                                    test_size=0.30, random_state=42)



hr_shape = (hr_train.shape[1], hr_train.shape[2], hr_train.shape[3])
lr_shape = (lr_train.shape[1], lr_train.shape[2], lr_train.shape[3])

lr_ip = Input(shape=lr_shape)
hr_ip = Input(shape=hr_shape)
num_res_block = 16
generator = create_gen(lr_ip, num_res_block)
generator.summary()

discriminator = create_disc(hr_ip)
discriminator.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
discriminator.summary()

vgg = build_vgg((128,128,3))
print(vgg.summary())
vgg.trainable = False

gan_model = create_comb(generator, discriminator, vgg, lr_ip, hr_ip)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   1792        ['input_19[0][0]']
#
#  p_re_lu_8 (PReLU)              (None, 32, 32, 64)   64          ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu_8[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d_9[0][0]']
#  alization)
#
#  p_re_lu_9 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_9[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 64)   0           ['p_re_lu_8[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_11[0][0]']
#  rmalization)
#
#  p_re_lu_10 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_10[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_12[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 64)   0           ['add[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_13[0][0]']
#  rmalization)
#
#  p_re_lu_11 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_11[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_14[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['add_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['add_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_15[0][0]']
#  rmalization)
#
#  p_re_lu_12 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_12[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_16[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['add_2[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   36928       ['add_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_17[0][0]']
#  rmalization)
#
#  p_re_lu_13 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_13[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_18[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 32, 32, 64)   0           ['add_3[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['add_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_10[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_14[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 64)   36928       ['add_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_12[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 64)   0           ['add_5[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 64)   36928       ['add_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_14[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_16[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 64)   0           ['add_6[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   36928       ['add_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_17 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_16[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_17[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 64)   0           ['add_7[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 64)   36928       ['add_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_18 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_18[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 32, 32, 64)   0           ['add_8[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 64)   36928       ['add_9[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_19 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_20[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_19[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['add_9[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 64)   36928       ['add_10[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  p_re_lu_20 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_22[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 64)   0           ['add_10[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 64)   36928       ['add_11[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  p_re_lu_21 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_24[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_21[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 32, 32, 64)   0           ['add_11[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 64)   36928       ['add_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  p_re_lu_22 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_26[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_22[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['add_12[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 64)   36928       ['add_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  p_re_lu_23 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_28[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_23[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 32, 32, 64)   0           ['add_13[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 64)   36928       ['add_14[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  p_re_lu_24 (PReLU)             (None, 32, 32, 64)   64          ['batch_normalization_30[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 64)   36928       ['p_re_lu_24[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 32, 32, 64)   0           ['add_14[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 64)   36928       ['add_15[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_32[0][0]',
#                                                                   'p_re_lu_8[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 256)  147712      ['add_16[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['conv2d_42[0][0]']
#
#  p_re_lu_25 (PReLU)             (None, 64, 64, 256)  256         ['up_sampling2d[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 64, 64, 256)  590080      ['p_re_lu_25[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_43[0][0]']
#                                 6)
#
#  p_re_lu_26 (PReLU)             (None, 128, 128, 25  256         ['up_sampling2d_1[0][0]']
#                                 6)
#
#  conv2d_44 (Conv2D)             (None, 128, 128, 3)  62211       ['p_re_lu_26[0][0]']
#
# ==================================================================================================
# Total params: 2,030,467
# Trainable params: 2,026,243
# Non-trainable params: 4,224
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 128, 128, 3)]     0
#
#  conv2d_45 (Conv2D)          (None, 128, 128, 64)      1792
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 64)      0
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 64)        36928
#
#  batch_normalization_33 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_34 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_35 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d_49 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_36 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_37 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  conv2d_51 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  batch_normalization_38 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16, 16, 512)       0
#
#  conv2d_52 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_39 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 1024)              33555456
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 38,249,281
# Trainable params: 38,245,569
# Non-trainable params: 3,712
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 32, 256)       590080
#
# =================================================================
# Total params: 2,325,568
# Trainable params: 2,325,568
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# and the reference image. 
gan_model.compile(loss=["binary_crossentropy", "mse"], loss_weights=[1e-3, 1], optimizer="adam", metrics=['accuracy'])
gan_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  model (Functional)             (None, 128, 128, 3)  2030467     ['input_19[0][0]']
#
#  input_20 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  model_1 (Functional)           (None, 1)            38249281    ['model[0][0]']
#
#  model_2 (Functional)           (None, 32, 32, 256)  2325568     ['model[0][0]']
#
# ==================================================================================================
# Total params: 42,605,316
# Trainable params: 2,026,243
# Non-trainable params: 40,579,073
# __________________________________________________________________________________________________

# %%
#Create a list of images for LR and HR in batches from which a batch of images
#would be fetched during training. 
batch_size = 1  
train_lr_batches = []
train_hr_batches = []
for it in range(int(hr_train.shape[0] / batch_size)):
    start_idx = it * batch_size
    end_idx = start_idx + batch_size
    train_hr_batches.append(hr_train[start_idx:end_idx])
    train_lr_batches.append(lr_train[start_idx:end_idx])

# %%
EPOCHS = 50
noise_dim = 100
num_examples_to_generate = 16

# You will reuse this seed overtime (so it's easier)
# to visualize progress in the animated GIF)
seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for image_batch in dataset:
      train_step(image_batch)

    # Produce images for the GIF as you go
    display.clear_output(wait=True)
    generate_and_save_images(generator,
                             epoch + 1,
                             seed)

    # Save the model every 15 epochs
    if (epoch + 1) % 15 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

  # Generate after the final epoch
  display.clear_output(wait=True)
  generate_and_save_images(generator,
                           epochs,
                           seed)

# %%
#Create a list of images for LR and HR in batches from which a batch of images
#would be fetched during training. 
batch_size = 1  
train_lr_batches = []
train_hr_batches = []
for it in range(int(hr_train.shape[0] / batch_size)):
    start_idx = it * batch_size
    end_idx = start_idx + batch_size
    train_hr_batches.append(hr_train[start_idx:end_idx])
    train_lr_batches.append(lr_train[start_idx:end_idx])

# %%
epochs = 50
#Enumerate training over epochs
for e in range(epochs):
    
    fake_label = np.zeros((batch_size, 1)) # Assign a label of 0 to all fake (generated images)
    real_label = np.ones((batch_size,1)) # Assign a label of 1 to all real images.
    
    #Create empty lists to populate gen and disc losses. 
    g_losses = []
    d_losses = []

# %%
   #Enumerate training over batches. 
   for b in tqdm(range(len(train_hr_batches))):
        lr_imgs = train_lr_batches[b] #Fetch a batch of LR images for training
        hr_imgs = train_hr_batches[b] #Fetch a batch of HR images for training
# Out:
# 100%|██████████| 700/700 [00:00<00:00, 1065703.38it/s]

# %%
fake_imgs = generator.predict_on_batch(lr_imgs) #Fake images

# %%
        #First, train the discriminator on fake and real HR images. 
discriminator.trainable = True
d_loss_gen = discriminator.train_on_batch(fake_imgs, fake_label)
d_loss_real = discriminator.train_on_batch(hr_imgs, real_label)

# %%
        #Now, train the generator by fixing discriminator as non-trainable
discriminator.trainable = False

# %%
        #Average the discriminator loss, just for reporting purposes. 
d_loss = 0.5 * np.add(d_loss_gen, d_loss_real)

# %%
        #Extract VGG features, to be used towards calculating loss
image_features = vgg.predict(hr_imgs)
# Out:
# 1/1 [==============================] - 1s 680ms/step

# %%
g_loss= gan_model.train_on_batch([lr_imgs, hr_imgs], [real_label, image_features])
print(g_loss)
# Out:
# [603821.8125, 6.664454460144043, 603821.8125, 0.0, 0.076171875]

# %%
from keras.models import load_model
from numpy.random import randint
#Save losses to a list so we can average and report. 
#d_losses.append(d_loss)
#g_losses.append(g_loss)
#Convert the list of losses to an array to make it easy to average    
g_losses = np.array(g_losses)
d_losses = np.array(d_losses)
#Calculate the average losses for generator and discriminator
g_loss = np.sum(g_losses, axis=0) / len(g_losses)
d_loss = np.sum(d_losses, axis=0) / len(d_losses)
#Report the progress during training. 
print("epoch:", e+1 ,"g_loss:", g_loss, "d_loss:", d_loss)

if (e+1) % 10 == 0: #Change the frequency for model saving, if needed
        #Save the generator after every n epochs (Usually 10 epochs)
        generator.save("gen_e_"+ str(e+1) +".h5")
#Test - perform super resolution using saved generator model
from keras.models import load_model
from numpy.random import randint

generator = load_model('gen_e_50.h5', compile=False)

[X1, X2] = [lr_test, hr_test]
# select random example
ix = randint(0, len(X1), 1)
src_image, tar_image = X1[ix], X2[ix]

# generate image from source
gen_image = generator.predict(src_image)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# epoch: 50 g_loss: [8.08487312e+05 1.02584684e+00 8.08487312e+05 0.00000000e+00
#  1.11328125e-01] d_loss: [1.55610576 0.5       ]
# 1/1 [==============================] - 1s 1s/step

# %%
# plot all three images

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('LR Image')
plt.imshow(src_image[0,:,:,:])
plt.subplot(232)
plt.title('Superresolution')
plt.imshow(gen_image[0,:,:,:])
plt.subplot(233)
plt.title('HR image')
plt.imshow(tar_image[0,:,:,:])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
